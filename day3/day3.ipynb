# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshan18-k/Harshan-codeboosters-2026/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
print("==== Warnings Ignored ====")
print("Pandas Installed :",pd.__version__)
print("Numpy Installed :",np.__version__)
print("Requests Installed :",requests.__version__)
print("==== Packages Installed Successfully ====")
# Out:
# ==== Warnings Ignored ====
# Pandas Installed : 2.2.2
# Numpy Installed : 2.0.2
# Requests Installed : 2.32.4
# ==== Packages Installed Successfully ====

# %%
data = pd.read_csv("/content/drive/MyDrive/Summer_Internship_2026/messy_sales_data.csv")
print("=== Data Loaded Successfully ===")
# Out:
# === Data Loaded Successfully ===

# %%
print("Data Loaded : ",data.shape[0]," Rows And ",data.shape[1]," Columns ")
# Out:
# Data Loaded :  30  Rows And  9  Columns

# %%
data.head()
# Out:
#    order_id customer_name   product     category  quantity  unit_price  \
# 0      1001  Ramesh Kumar    Laptop  Electronics       2.0       45000
# 1      1002    Priya Nair       NaN  Electronics       1.0       15000
# 2      1003    AMIT VERMA  Keyboard  Accessories       3.0        1200
# 3      1004  Sunita Patel   Monitor  Electronics       NaN       22000
# 4      1005  Ramesh Kumar    Laptop  Electronics       2.0       45000
#
#    order_date       city    sales_rep
# 0  2024-01-05     Mumbai  Anil Sharma
# 1  2024-01-07      Delhi   Sunita Rao
# 2  2024-01-08  Bangalore  Anil Sharma
# 3  2024-01-10    Chennai   Ravi Kumar
# 4  2024-01-05     Mumbai  Anil Sharma

# %%
print("=== Data Quantity Analysis ===")
print("")
print("Number of Missing values")
print(data.isnull().sum())
print("="*40)
print("Number of Duplicate Values")
print(data.duplicated().sum())
print("="*40)
print("Data Types of the elements")
print(data.dtypes)
# Out:
# === Data Quantity Analysis ===
#
# Number of Missing values
# order_id         0
# customer_name    2
# product          1
# category         1
# quantity         3
# unit_price       0
# order_date       0
# city             0
# sales_rep        0
# dtype: int64
# ...
# Number of Duplicate Values
# 0
# ...
# Data Types of the elements
# order_id           int64
# customer_name     object
# product           object
# category          object
# quantity         float64
# unit_price         int64
# order_date        object
# city              object
# sales_rep         object
# dtype: object

# %%
print("=== Unique category name ===")
print(data['category'].unique())
print("")
print("=== Sample Customer name ===")
print(data['customer_name'].dropna().unique()[:8])
print("")
print("=== Order Date analysis ===")
print(data['order_date'].unique()[:6])
# Out:
# === Unique category name ===
# ['Electronics' 'Accessories' nan]
#
# === Sample Customer name ===
# ['Ramesh Kumar' 'Priya Nair' 'AMIT VERMA' 'Sunita Patel' 'kiran mehta'
#  'Deepak Singh' 'Ananya Das' 'Vikram Iyer']
#
# === Order Date analysis ===
# ['2024-01-05' '2024-01-07' '2024-01-08' '2024-01-10' '07-01-2024'
#  '2024-01-12']

# %%
print("Number of Missing values")
print(data['quantity'].isnull().sum())
print("-"*40)
print("Number of Duplicate Values")
print(data['quantity'].duplicated().sum())
# Out:
# Number of Missing values
# 3
# ----------------------------------------
# Number of Duplicate Values
# 20

# %%
#copying the dataset to avoid the lose of data using copy() function

df = data.copy()
df.head()
# Out:
#    order_id customer_name   product     category  quantity  unit_price  \
# 0      1001  Ramesh Kumar    Laptop  Electronics       2.0       45000
# 1      1002    Priya Nair       NaN  Electronics       1.0       15000
# 2      1003    AMIT VERMA  Keyboard  Accessories       3.0        1200
# 3      1004  Sunita Patel   Monitor  Electronics       NaN       22000
# 4      1005  Ramesh Kumar    Laptop  Electronics       2.0       45000
#
#    order_date       city    sales_rep
# 0  2024-01-05     Mumbai  Anil Sharma
# 1  2024-01-07      Delhi   Sunita Rao
# 2  2024-01-08  Bangalore  Anil Sharma
# 3  2024-01-10    Chennai   Ravi Kumar
# 4  2024-01-05     Mumbai  Anil Sharma

# %%
print(df)
# Out:
#     order_id  customer_name     product     category  quantity  unit_price  \
# 0       1001   Ramesh Kumar      Laptop  Electronics       2.0       45000
# 1       1002     Priya Nair         NaN  Electronics       1.0       15000
# 2       1003     AMIT VERMA    Keyboard  Accessories       3.0        1200
# 3       1004   Sunita Patel     Monitor  Electronics       NaN       22000
# 4       1005   Ramesh Kumar      Laptop  Electronics       2.0       45000
# 5       1006    kiran mehta       Mouse  Accessories      10.0         800
# 6       1007   Deepak Singh  Headphones  Electronics       2.0        3500
# 7       1008            NaN      Webcam  Accessories       1.0        2500
# 8       1009     Ananya Das      Laptop  Electronics       1.0       45000
# 9       1010    Vikram Iyer    Keyboard  Accessories       5.0        1200
# 10      1011    Pooja Gupta     Monitor  Electronics       2.0       22000
# ...

# %%
print(df.columns)
# Out:
# Index(['order_id', 'customer_name', 'product', 'category', 'quantity',
#        'unit_price', 'order_date', 'city', 'sales_rep'],
#       dtype='object')

# %%
print(data['quantity'].isnull().sum())
print("=== Finding the Total Missing Values in the copied Dataset ===")
print(df.isnull().sum().sum())
# Out:
# 3
# === Finding the Total Missing Values in the copied Dataset ===
# 7

# %%
df['customer_name'].fillna('Unknown Customer' ,inplace = True)
print(df['customer_name'])
# Out:
# 0         Ramesh Kumar
# 1           Priya Nair
# 2           AMIT VERMA
# 3         Sunita Patel
# 4         Ramesh Kumar
# 5          kiran mehta
# 6         Deepak Singh
# 7     Unknown Customer
# 8           Ananya Das
# 9          Vikram Iyer
# 10         Pooja Gupta
# 11          SURESH RAO
# 12         Meera Joshi
# 13          Arjun Nair
# 14         Tanvi Mehta
# 15         Kiran Mehta
# 16        Deepak Singh
# 17         Rohit Verma
# 18         Sneha Reddy
# 19       Gaurav Shukla
# 20        Nisha Kapoor
# 21         Ajay Tiwari
# 22          ANANYA DAS
# 23       Preeti Saxena
# 24           Amit Bose
# 25    Unknown Customer
# 26          Rekha Nair
# 27       Harish Pillai
# 28        Sanjay Dubey
# 29       Kavya Nambiar
# Name: customer_name, dtype: object

# %%
df['customer_name'].fillna('Unknown Customer')
# Out:
# 0         Ramesh Kumar
# 1           Priya Nair
# 2           AMIT VERMA
# 3         Sunita Patel
# 4         Ramesh Kumar
# 5          kiran mehta
# 6         Deepak Singh
# 7     Unknown Customer
# 8           Ananya Das
# 9          Vikram Iyer
# 10         Pooja Gupta
# 11          SURESH RAO
# 12         Meera Joshi
# 13          Arjun Nair
# 14         Tanvi Mehta
# 15         Kiran Mehta
# 16        Deepak Singh
# 17         Rohit Verma
# 18         Sneha Reddy
# 19       Gaurav Shukla
# 20        Nisha Kapoor
# 21         Ajay Tiwari
# 22          ANANYA DAS
# 23       Preeti Saxena
# 24           Amit Bose
# 25    Unknown Customer
# 26          Rekha Nair
# 27       Harish Pillai
# 28        Sanjay Dubey
# 29       Kavya Nambiar
# Name: customer_name, dtype: object

# %%
# Fill numeric columns with mean
df['quantity'].fillna(df['quantity'].mean(), inplace=True)
df['quantity'].fillna(df['quantity'].mean())
# Out:
# 0      2.000000
# 1      1.000000
# 2      3.000000
# 3      3.925926
# 4      2.000000
# 5     10.000000
# 6      2.000000
# 7      1.000000
# 8      1.000000
# 9      5.000000
# 10     2.000000
# 11     8.000000
# 12     3.925926
# 13     3.000000
# 14     2.000000
# 15    10.000000
# 16     5.000000
# 17     1.000000
# 18     1.000000
# 19    15.000000
# 20     2.000000
# 21     3.000000
# 22     1.000000
# 23     4.000000
# 24     6.000000
# 25     1.000000
# 26     2.000000
# 27     3.000000
# 28    10.000000
# 29     3.925926
# Name: quantity, dtype: float64

# %%
# Fill categorical columns with mode
df['city'].fillna(df['city'].mode()[0], inplace=True)
df['city'].fillna(df['city'].mode()[0])
# Out:
# 0                 Mumbai
# 1                  Delhi
# 2              Bangalore
# 3                Chennai
# 4                 Mumbai
# 5                   Pune
# 6              Hyderabad
# 7                 Mumbai
# 8                Kolkata
# 9                Chennai
# 10                 Delhi
# 11             Bangalore
# 12                  Pune
# 13                 Kochi
# 14                 Surat
# 15                  Pune
# 16             Hyderabad
# 17                 Delhi
# 18             Hyderabad
# 19               Lucknow
# 20            Chandigarh
# 21                Bhopal
# 22               Kolkata
# 23                Kanpur
# 24               Kolkata
# 25                Mumbai
# 26                 Kochi
# 27    Thiruvananthapuram
# 28             Allahabad
# 29              Thrissur
# Name: city, dtype: object

# %%
print("\nAfter Fixing Missing Values:")
print(df.isnull().sum())
print("\nTotal Missing Values:", df.isnull().sum().sum())
# Out:
# After Fixing Missing Values:
# order_id         0
# customer_name    0
# product          1
# category         1
# quantity         0
# unit_price       0
# order_date       0
# city             0
# sales_rep        0
# dtype: int64
#
# Total Missing Values: 2

# %%
print("=== Total Missing Values in Product ===")
print(df['product'].isnull().sum())
df['product'].fillna(df['product'].mode()[0],inplace = True)
df['product'].fillna(df['product'].mode()[0])
# Out:
# === Total Missing Values in Product ===
# 0
# 0         Laptop
# 1         Laptop
# 2       Keyboard
# 3        Monitor
# 4         Laptop
# 5          Mouse
# 6     Headphones
# 7         Webcam
# 8         Laptop
# 9       Keyboard
# 10       Monitor
# 11       USB Hub
# 12        Laptop
# 13    Headphones
# 14        Webcam
# 15         Mouse
# 16      Keyboard
# 17       Monitor
# 18        Laptop
# 19       USB Hub
# 20    Headphones
# 21        Webcam
# 22        Laptop
# 23      Keyboard
# 24         Mouse
# 25    Headphones
# 26       Monitor
# 27        Laptop
# 28       USB Hub
# 29        Webcam
# Name: product, dtype: object

# %%
print("=== Total Missing Values in Product ===")
print(df['product'].isnull().sum())
# Out:
# === Total Missing Values in Product ===
# 0

# %%
print("Before Deduplication : ",len(df),"rows")
print("Duplicate Rows : ",df.duplicated().sum())
print(df[df.duplicated(keep = False)][['order_id', 'customer_name', 'product', 'category', 'quantity',
       'unit_price', 'order_date', 'city', 'sales_rep']])
df.drop_duplicates(inplace = True)
print("After Deduplication : ",len(df),"rows")
print("Removed Rows : ",len(data) - len(df))
# Out:
# Before Deduplication :  30 rows
# Duplicate Rows :  0
# Empty DataFrame
# Columns: [order_id, customer_name, product, category, quantity, unit_price, order_date, city, sales_rep]
# Index: []
# After Deduplication :  30 rows
# Removed Rows :  0

# %%
print("=== Sample Dates Before parsing ===")
print(df['order_date'].head(8).tolist())

df['order_date'] = pd.to_datetime(
    df['order_date'],
    dayfirst=False,
    errors='coerce'
)
nat_count = df['order_date'].isnull().sum()
print("Unparsable dates : ",nat_count)
df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month
df['month_name'] = df['order_date'].dt.strftime('%B')
print("=== sample dates after parsing ===")
print(df[['order_date','year','month','month_name']].head(8))
# Out:
# === Sample Dates Before parsing ===
# [Timestamp('2024-01-05 00:00:00'), Timestamp('2024-01-07 00:00:00'), Timestamp('2024-01-08 00:00:00'), Timestamp('2024-01-10 00:00:00'), Timestamp('2024-01-05 00:00:00'), NaT, Timestamp('2024-01-12 00:00:00'), Timestamp('2024-01-13 00:00:00')]
# Unparsable dates :  2
# === sample dates after parsing ===
#   order_date    year  month month_name
# 0 2024-01-05  2024.0    1.0    January
# 1 2024-01-07  2024.0    1.0    January
# 2 2024-01-08  2024.0    1.0    January
# 3 2024-01-10  2024.0    1.0    January
# 4 2024-01-05  2024.0    1.0    January
# 5        NaT     NaN    NaN        NaN
# 6 2024-01-12  2024.0    1.0    January
# 7 2024-01-13  2024.0    1.0    January

# %%
df['order_date'] = pd.to_datetime(df['order_date'], format='mixed', dayfirst=True, errors='coerce')
df['day'] = df['order_date'].dt.day
df['month'] = df['order_date'].dt.month
df['year'] = df['order_date'].dt.year
df['month_name'] = df['order_date'].dt.strftime('%B')

print("DataFrame with 'day', 'month', 'year', and 'month_name' columns:")
print(df[['order_date', 'day', 'month', 'year', 'month_name']].head())
# Out:
# DataFrame with 'day', 'month', 'year', and 'month_name' columns:
#   order_date   day  month    year month_name
# 0 2024-01-05   5.0    1.0  2024.0    January
# 1 2024-01-07   7.0    1.0  2024.0    January
# 2 2024-01-08   8.0    1.0  2024.0    January
# 3 2024-01-10  10.0    1.0  2024.0    January
# 4 2024-01-05   5.0    1.0  2024.0    January
