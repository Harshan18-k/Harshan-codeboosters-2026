# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshan18-k/Harshan-codeboosters-2026/blob/main/day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# MACHINE LEARNING AND TRAINING MODELS

# TYPES OF MACHINE LEARNING

# -> SUPERVISED LEARNING
#    (CLASSIFICATION AND REGRESSION)

# CLASSIFICATION : IT WILL BE BASED ON CLASSIFYING LIKE HIGH , LOW AND MEDIUM
# REGRESSION : IT WILL BE PREDICTING THE LEVEL AS A NUMERIC SUCH AS CALCULATING RESUME SCORE

# -> UNSUPERVISED LEARNING
#    (CLUSTERING AND DIMENSIONALITY REDUCTION)

# CLUSTERING : GROUPING THE CLUSTER FOR A REQUIRED OUTCOME PREDICTION
# DIMENSIONALITY REDUCTION : REDUCING THE DIMENSIONS TO AVOID THE UNNECESSARY OUTCOME CLUSTERING AND REDUCTION OF TIME COMPLEXITY

# DATA ENGINEERING AND ML PIPELINING

# === ML PIPELINE ===

# RAW DATA
# STORE & QUERY
# ETL / CLEAN
# FEATURE ENGINEERING
# TRAIN MODEL
# EVALUATE
# PREDICT

print("=== Refer Notes ===")
# Out:
# === Refer Notes ===

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

print("All Libraries Imported Sucessfully !!!!")
# Out:
# All Libraries Imported Sucessfully !!!!

# %%
df = pd.read_csv("/content/drive/MyDrive/Summer_Internship_2026/student_performance.csv")
print("Data loaded : ",df.shape[0],"students",df.shape[1],"Columns")
print("Column Name : ",df.columns.to_list())
# Out:
# Data loaded :  30 students 13 Columns
# Column Name :  ['student_id', 'name', 'age', 'gender', 'department', 'semester', 'math_score', 'science_score', 'english_score', 'programming_score', 'attendance_percentage', 'city', 'admission_year']

# %%
print("=== Programming Score Statistics ===")
print(df['programming_score'].describe())
# Out:
# === Programming Score Statistics ===
# count    30.000000
# mean     67.600000
# std      21.041175
# min      38.000000
# 25%      49.250000
# 50%      66.000000
# 75%      88.750000
# max      97.000000
# Name: programming_score, dtype: float64

# %%
print("=== GENDER ENCODING ===")
df_ml = df.copy()
le_gender = LabelEncoder()
df_ml['gender'] = le_gender.fit_transform(df_ml['gender'])
print(f"Gender encoding : {dict(zip(le_gender.classes_,le_gender.transform(le_gender.classes_)))}")
# Out:
# === GENDER ENCODING ===
# Gender encoding : {'Female': np.int64(0), 'Male': np.int64(1)}

# %%
print("=== DEPARTMENT ENCODING ===")
le_dept = LabelEncoder()
df_ml['department'] = le_dept.fit_transform(df_ml['department'])
print(f"Department Encoding : {dict(zip(le_dept.classes_,le_dept.transform(le_dept.classes_)))}")
# Out:
# === DEPARTMENT ENCODING ===
# Department Encoding : {'Civil': np.int64(0), 'Computer Science': np.int64(1), 'Electronics': np.int64(2), 'Mechanical': np.int64(3)}

# %%
print("=== SEMESTER ENCODING ===")
le_sem = LabelEncoder()
df_ml['semester'] = le_sem.fit_transform(df_ml['semester'])
print(f"Semester Encoding : {dict(zip(le_sem.classes_,le_sem.transform(le_sem.classes_)))}")
# Out:
# === SEMESTER ENCODING ===
# Semester Encoding : {np.int64(2): np.int64(0)}

# %%
feature_col = [
    'math_score',
    'science_score',
    'attendance_percentage',
    'gender',
    'department'
]
x = df_ml[feature_col]
y = df_ml['programming_score']
print("Feature Matrix X shape : ",x.shape)
print("Target Vector Y shape : ",y.shape)
print(f"Target Range from  {y.min()} to {y.max()} mean : {y.mean():.1f}") # Corrected y.min and y.max to be functions
# Out:
# Feature Matrix X shape :  (30, 5)
# Target Vector Y shape :  (30,)
# Target Range from  38 to 97 mean : 67.6

# %%
X_train , X_test ,Y_train , Y_test = train_test_split(
    x,
    y,
    test_size = 0.2,
    random_state = 42
)
print(f"Total Students : {len(x)}")
print(f"Training Students : {len(X_train)} : ({len(X_train)/len(x)*100:.0f}) %")
print(f"Testing Students : {len(X_test)} ({len(X_test)/len(x)*100:.0f})")
print(f"Traininf target Range {Y_train.min()} to {Y_train.max()} mean : {Y_train.mean():.1f}")
print(f"Testing target Range {Y_test.min()} to {Y_test.max()} mean : {Y_test.mean():.1f}")
# Out:
# Total Students : 30
# Training Students : 24 : (80) %
# Testing Students : 6 (20)
# Traininf target Range 38 to 96 mean : 68.0
# Testing target Range 39 to 97 mean : 65.8

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
print("=== Features Scaled Sucessfully ===")
X_test_scaled =  scaler.transform(X_test)
print(f"Training feature mean (should be 0 ) : {X_train_scaled.mean():.4f}")
print("Traing feature Std (should be -1 ) : ",X_train_scaled.std())
# Out:
# === Features Scaled Sucessfully ===
# Training feature mean (should be 0 ) : -0.0000
# Traing feature Std (should be -1 ) :  1.0

# %%
lr_model = LinearRegression()
lr_model.fit(X_train_scaled,Y_train)
lr_pred = lr_model.predict(X_test_scaled)

lr_mae = mean_absolute_error(Y_test,lr_pred)
lr_mse = np.sqrt(mean_squared_error(Y_test,lr_pred))
lr_r2 = r2_score(Y_test,lr_pred)
lr_rmse = np.sqrt(lr_mse)

print("=== MODEL IN LINEAR REGRESSION ===")
print(f"MAE : {lr_mae:.2f}")
print(f"MSE : {lr_mse:.2f}")
print(f"R2 : {lr_r2:.4f}")
print(f"RMSE : {lr_rmse:.2f}")
# Out:
# === MODEL IN LINEAR REGRESSION ===
# MAE : 9.84
# MSE : 11.88
# R2 : 0.7164
# RMSE : 3.45

# %%
dt_model = DecisionTreeRegressor(
    max_depth = 5,
    random_state = 42
)
dt_model.fit(X_train,Y_train)
dt_pred = dt_model.predict(X_test_scaled)

dt_mae = mean_absolute_error(Y_test,dt_pred)
dt_mse = mean_squared_error(Y_test,dt_pred)
dt_rmse = np.sqrt(mean_squared_error(Y_test,dt_pred))
dt_r2 = r2_score(Y_test,dt_pred)\

print("=== DECISION TREE REGRESSION IN ===")
print(f"MAE : {dt_mae:.2f}")
print(f"MSE : {dt_mse:.2f}")
print(f"R2 : {dt_r2:.4f}")
print(f"RMSE : {dt_rmse:.2f}")
# Out:
# === DECISION TREE REGRESSION IN ===
# MAE : 9.25
# MSE : 171.38
# R2 : 0.6555
# RMSE : 13.09
